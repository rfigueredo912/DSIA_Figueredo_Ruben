# %% [markdown]
# # 📊 Trabajo Práctico \- Análisis Exploratorio de Datos \(EDA\)

# %% [markdown]
# ## Materia: Desarrollo de Sistemas de Inteligencia Artificial

# %% [markdown]
# ## Grupo N°

# %% [markdown]
# ### Integrantes del grupo:

# %% [markdown]
# Nombre Apellido 1 \- Dataset: \[Nombre del dataset 1\]
# Nombre Apellido 2 \- Dataset: \[Nombre del dataset 2\]
# Nombre Apellido 3 \- Dataset: \[Nombre del dataset 3\]
# Nombre Apellido 4 \- Dataset: \[Nombre del dataset 4\]
# Nombre Apellido 5 \- Dataset: \[Nombre del dataset 5\]
# Nombre Apellido 6 \- Dataset: \[Nombre del dataset 6\]

# %% [markdown]
# # PRIMERA ENTREGA

# %% [markdown]
# ## 👉🏻 Consigna

# %% [markdown]
# Cada integrante del grupo trabajó con un conjunto de datos distinto, cumpliendo con los requisitos mínimos: formato \.csv o \.xlsx, al menos 9 columnas y 2500 filas\. En este notebook se integran todos los análisis exploratorios individuales, seguidos por una conclusión grupal que justifica la elección del dataset con el que se continuará el desarrollo del proyecto\.

# %% [markdown]
# ## 🔍 Introducción

# %% [markdown]
# Cada integrante del grupo trabajó con un conjunto de datos distinto, cumpliendo con los requisitos mínimos: formato \.csv o \.xlsx, al menos 9 columnas y 2500 filas\. En este notebook se integran todos los análisis exploratorios individuales, seguidos por una conclusión grupal que justifica la elección del dataset con el que se continuará el desarrollo del proyecto\.

# %% [markdown]
# # 📁 Dataset 1 – \[Nombre del dataset 1\] \(Integrante: Nombre Apellido\)

# %% [markdown]
# ## 📝 Descripción del Dataset

# %% [markdown]
# Describir de que se trata el dataset

# %% [markdown]
# ## Importación de Librerías

# %%
#Importación de librerías

# %% [markdown]
# ## 1\. Carga y exploración de datos

# %% [markdown]
# ###  \[Nombre de la acción\]

# %% [markdown]
# Introducción a la acción

# %%
# Código para cargar el dataset y mostrar estructura

# %% [markdown]
# Interpretación de la acción

# %% [markdown]
# ###  \[Nombre de la acción\]

# %% [markdown]
# Introducción a la acción

# %%
# Código para analizar el dataset y mostrar estructura

# %% [markdown]
# Interpretación de la acción

# %% [markdown]
# ## 2\. Visualizaciones y análisis

# %% [markdown]
# ###  \[Nombre del gráfico\]

# %% [markdown]
# Introducción al Gráfico 1

# %%
#Gráfico 1

# %% [markdown]
# 📌 Interpretación del gráfico

# %% [markdown]
# ###  \[Nombre del gráfico\]

# %% [markdown]
# Introducción al Gráfico 2

# %%
#Gráfico 2

# %% [markdown]
# 📌 Interpretación del gráfico

# %% [markdown]
# ## 3\. Observaciones generales

# %% [markdown]
# Breve resumen del análisis: ¿Qué patrones se observan? ¿Hay calidad en los datos? ¿Qué variables resultan más interesantes?

# %% [markdown]
# # 📁 Dataset 2 – \[Nombre del dataset 2\] \(Integrante: Nombre Apellido\)

# %% [markdown]
# ## 📝 Descripción del Dataset

# %% [markdown]
# Describir de que se trata el dataset

# %% [markdown]
# ## Importación de Librerías

# %%
#Importación de librerías

# %% [markdown]
# ## 1\. Carga y exploración de datos

# %% [markdown]
# ###  \[Nombre de la acción\]

# %% [markdown]
# Introducción a la acción

# %%
# Código para cargar el dataset y mostrar estructura

# %% [markdown]
# Interpretación de la acción

# %% [markdown]
# ###  \[Nombre de la acción\]

# %% [markdown]
# Introducción a la acción

# %%
# Código para analizar el dataset y mostrar estructura

# %% [markdown]
# Interpretación de la acción

# %% [markdown]
# ## 2\. Visualizaciones y análisis

# %% [markdown]
# ###  \[Nombre del gráfico\]

# %% [markdown]
# Introducción al Gráfico 1

# %%
#Gráfico 1

# %% [markdown]
# 📌 Interpretación del gráfico

# %% [markdown]
# ###  \[Nombre del gráfico\]

# %% [markdown]
# Introducción al Gráfico 2

# %%
#Gráfico 2

# %% [markdown]
# 📌 Interpretación del gráfico

# %% [markdown]
# ## 3\. Observaciones generales

# %% [markdown]
# Breve resumen del análisis: ¿Qué patrones se observan? ¿Hay calidad en los datos? ¿Qué variables resultan más interesantes?

# %% [markdown]
# # 📁 Dataset 3 – \[Nombre del dataset 3\] \(Integrante: Nombre Apellido\)

# %% [markdown]
# ## 📝 Descripción del Dataset

# %% [markdown]
# Describir de que se trata el dataset

# %% [markdown]
# ## Importación de Librerías

# %%
#Importación de librerías

# %% [markdown]
# ## 1\. Carga y exploración de datos

# %% [markdown]
# ###  \[Nombre de la acción\]

# %% [markdown]
# Introducción a la acción

# %%
# Código para cargar el dataset y mostrar estructura

# %% [markdown]
# Interpretación de la acción

# %% [markdown]
# ###  \[Nombre de la acción\]

# %% [markdown]
# Introducción a la acción

# %%
# Código para analizar el dataset y mostrar estructura

# %% [markdown]
# Interpretación de la acción

# %% [markdown]
# ## 2\. Visualizaciones y análisis

# %% [markdown]
# ###  \[Nombre del gráfico\]

# %% [markdown]
# Introducción al Gráfico 1

# %%
#Gráfico 1

# %% [markdown]
# 📌 Interpretación del gráfico

# %% [markdown]
# ###  \[Nombre del gráfico\]

# %% [markdown]
# Introducción al Gráfico 2

# %%
#Gráfico 2

# %% [markdown]
# 📌 Interpretación del gráfico

# %% [markdown]
# ## 3\. Observaciones generales

# %% [markdown]
# Breve resumen del análisis: ¿Qué patrones se observan? ¿Hay calidad en los datos? ¿Qué variables resultan más interesantes?

# %% [markdown]
# ##

# %% [markdown]
# # 📁 Dataset 4 – \[Nombre del dataset 4\] \(Integrante: Nombre Apellido\)

# %% [markdown]
# ## 📝 Descripción del Dataset

# %% [markdown]
# Describir de que se trata el dataset

# %% [markdown]
# ## Importación de Librerías

# %%
#Importación de librerías

# %% [markdown]
# ## 1\. Carga y exploración de datos

# %% [markdown]
# ###  \[Nombre de la acción\]

# %% [markdown]
# Introducción a la acción

# %%
# Código para cargar el dataset y mostrar estructura

# %% [markdown]
# Interpretación de la acción

# %% [markdown]
# ###  \[Nombre de la acción\]

# %% [markdown]
# Introducción a la acción

# %%
# Código para analizar el dataset y mostrar estructura

# %% [markdown]
# Interpretación de la acción

# %% [markdown]
# ## 2\. Visualizaciones y análisis

# %% [markdown]
# ###  \[Nombre del gráfico\]

# %% [markdown]
# Introducción al Gráfico 1

# %%
#Gráfico 1

# %% [markdown]
# 📌 Interpretación del gráfico

# %% [markdown]
# ###  \[Nombre del gráfico\]

# %% [markdown]
# Introducción al Gráfico 2

# %%
#Gráfico 2

# %% [markdown]
# 📌 Interpretación del gráfico

# %% [markdown]
# ## 3\. Observaciones generales

# %% [markdown]
# Breve resumen del análisis: ¿Qué patrones se observan? ¿Hay calidad en los datos? ¿Qué variables resultan más interesantes?

# %% [markdown]
# # 📁 Dataset 5 – \[Nombre del dataset 5\] \(Integrante: Nombre Apellido\)

# %% [markdown]
# ## 📝 Descripción del Dataset

# %% [markdown]
# Describir de que se trata el dataset

# %% [markdown]
# ## Importación de Librerías

# %%
#Importación de librerías

# %% [markdown]
# ## 1\. Carga y exploración de datos

# %% [markdown]
# ###  \[Nombre de la acción\]

# %% [markdown]
# Introducción a la acción

# %%
# Código para cargar el dataset y mostrar estructura

# %% [markdown]
# Interpretación de la acción

# %% [markdown]
# ###  \[Nombre de la acción\]

# %% [markdown]
# Introducción a la acción

# %%
# Código para analizar el dataset y mostrar estructura

# %% [markdown]
# Interpretación de la acción

# %% [markdown]
# ## 2\. Visualizaciones y análisis

# %% [markdown]
# ###  \[Nombre del gráfico\]

# %% [markdown]
# Introducción al Gráfico 1

# %%
#Gráfico 1

# %% [markdown]
# 📌 Interpretación del gráfico

# %% [markdown]
# ###  \[Nombre del gráfico\]

# %% [markdown]
# Introducción al Gráfico 2

# %%
#Gráfico 2

# %% [markdown]
# 📌 Interpretación del gráfico

# %% [markdown]
# ## 3\. Observaciones generales

# %% [markdown]
# Breve resumen del análisis: ¿Qué patrones se observan? ¿Hay calidad en los datos? ¿Qué variables resultan más interesantes?

# %% [markdown]
# # 📁 Dataset 6 – \[Nombre del dataset 6\] \(Integrante: Nombre Apellido\)

# %% [markdown]
# ## 📝 Descripción del Dataset

# %% [markdown]
# Describir de que se trata el dataset

# %% [markdown]
# ## Importación de Librerías

# %%
#Importación de librerías

# %% [markdown]
# ## 1\. Carga y exploración de datos

# %% [markdown]
# ###  \[Nombre de la acción\]

# %% [markdown]
# Introducción a la acción

# %%
# Código para cargar el dataset y mostrar estructura

# %% [markdown]
# Interpretación de la acción

# %% [markdown]
# ###  \[Nombre de la acción\]

# %% [markdown]
# Introducción a la acción

# %%
# Código para analizar el dataset y mostrar estructura

# %% [markdown]
# Interpretación de la acción

# %% [markdown]
# ## 2\. Visualizaciones y análisis

# %% [markdown]
# ###  \[Nombre del gráfico\]

# %% [markdown]
# Introducción al Gráfico 1

# %%
#Gráfico 1

# %% [markdown]
# 📌 Interpretación del gráfico

# %% [markdown]
# ###  \[Nombre del gráfico\]

# %% [markdown]
# Introducción al Gráfico 2

# %%
#Gráfico 2

# %% [markdown]
# 📌 Interpretación del gráfico

# %% [markdown]
# ## 3\. Observaciones generales

# %% [markdown]
# Breve resumen del análisis: ¿Qué patrones se observan? ¿Hay calidad en los datos? ¿Qué variables resultan más interesantes?

# %% [markdown]
# # ✅ Conclusión del equipo

# %% [markdown]
# Después de analizar todos los datasets, el equipo ha decidido continuar el trabajo con el dataset:

# %% [markdown]
# ## 🏆 Dataset elegido: \[Nombre del dataset\]

# %% [markdown]
# ## 📌 Motivos de la elección:

# %% [markdown]
# - Es el más completo en cuanto a variables y registros\.

# %% [markdown]
# - Tiene información actualizada/relevante para una problemática interesante\.

# %% [markdown]
# - Se visualiza potencial para aplicar técnicas de IA en próximas etapas \(clasificación, predicción, clustering, etc\.\)\.

# %% [markdown]
# - \(Agregar cualquier otra razón que les parezca relevante\)

# %% [markdown]
# ## 💡 Próximos pasos

# %% [markdown]
# - Limpieza y preparación del dataset elegido\.

# %% [markdown]
# - Diseño de una solución basada en la problemática detectada\.

# %% [markdown]
# - Implementación y validación del modelo\.

# %% [markdown]
# # SEGUNDA ENTREGA

# %% [markdown]
# ## 👉🏻 Consigna

# %% [markdown]
# Entregar por grupo un solo notebook trabajando sobre el dataset elegido por el equipo\. El notebook debe incluir lo siguiente:

# %% [markdown]
# Análisis EDA \(según lo trabajaron en la entrega 1\)
# Análisis univariado, bivariado y/o multivariado
# 4 hipótesis sobre el dataset
# Gráficas orientadas a la respuesta de estas 4 hipótesis
# Limpieza del dataset en caso de ser necesaria\.

# %% [markdown]
# ## 🔍 Introducción

# %% [markdown]
# Vamos a \.\.\.

# %% [markdown]
# # 📁 Dataset seleccionado– \[Nombre del dataset\]

# %% [markdown]
# ## 📝 Descripción del Dataset

# %% [markdown]
# Describir de que se trata el dataset

# %% [markdown]
# ## Importación de Librerías

# %%
#Importación de librerías

# %% [markdown]
# ## 1\. Carga y exploración de datos

# %% [markdown]
# ###  \[Nombre de la acción\]

# %% [markdown]
# Introducción a la acción

# %%
# Código para cargar el dataset y mostrar estructura

# %% [markdown]
# Interpretación de la acción

# %% [markdown]
# ###  \[Nombre de la acción\]

# %% [markdown]
# Introducción a la acción

# %%
# Código para analizar el dataset y mostrar estructura

# %% [markdown]
# Interpretación de la acción

# %% [markdown]
# ## 2\. Limpieza de Datos

# %% [markdown]
# ## Analisis Univariado

# %% [markdown]
# ###  \[Nombre del gráfico\]

# %% [markdown]
# Introducción al Gráfico 1

# %%
#Gráfico 1

# %% [markdown]
# 📌 Interpretación del gráfico

# %% [markdown]
# Breve resumen del análisis: ¿Qué patrones se observan? ¿Hay calidad en los datos? ¿Qué variables resultan más interesantes?

# %% [markdown]
# ## 3\. Visualizaciones y análisis

# %% [markdown]
# ## Analisis Univariado

# %% [markdown]
# ###  \[Nombre del gráfico\]

# %% [markdown]
# Introducción al Gráfico 1

# %%
#Gráfico 1

# %% [markdown]
# 📌 Interpretación del gráfico

# %% [markdown]
# Breve resumen del análisis: ¿Qué patrones se observan? ¿Hay calidad en los datos? ¿Qué variables resultan más interesantes?

# %% [markdown]
# ## Analisis Bivariado

# %% [markdown]
# ###  \[Nombre del gráfico\]

# %% [markdown]
# Introducción al Gráfico 1

# %%
#Gráfico 1

# %% [markdown]
# 📌 Interpretación del gráfico

# %% [markdown]
# ###  \[Nombre del gráfico\]

# %% [markdown]
# Introducción al Gráfico 2

# %%
#Gráfico 2

# %% [markdown]
# 📌 Interpretación del gráfico

# %% [markdown]
# ###  \[Nombre del gráfico\]

# %% [markdown]
# Introducción al Gráfico 3

# %%
#Gráfico 3

# %% [markdown]
# 📌 Interpretación del gráfico

# %% [markdown]
# Breve resumen del análisis: ¿Qué patrones se observan? ¿Hay calidad en los datos? ¿Qué variables resultan más interesantes?

# %% [markdown]
# ## Analisis Multivariado

# %% [markdown]
# ###  \[Nombre del gráfico\]

# %% [markdown]
# Introducción al Gráfico 1

# %%
#Gráfico 1

# %% [markdown]
# 📌 Interpretación del gráfico

# %% [markdown]
# ###  \[Nombre del gráfico\]

# %% [markdown]
# Introducción al Gráfico 2

# %%
#Gráfico 2

# %% [markdown]
# 📌 Interpretación del gráfico

# %% [markdown]
# ###  \[Nombre del gráfico\]

# %% [markdown]
# Introducción al Gráfico 3

# %%
#Gráfico 3

# %% [markdown]
# 📌 Interpretación del gráfico

# %% [markdown]
# Breve resumen del análisis: ¿Qué patrones se observan? ¿Hay calidad en los datos? ¿Qué variables resultan más interesantes?

# %% [markdown]
# ## 4\. Planteo de Hipótesis

# %% [markdown]
# ###  \[Hipótesis 1\]

# %% [markdown]
# Introducción Hipótesis

# %%
#desarrollo Hipótesis

# %%
#Grafico Hipótesis

# %% [markdown]
# Explicación de lo que se desarrolló para ver si se cumple o no la hipótesis planteada

# %% [markdown]
# La Hipótesis se cumple o no se cumple

# %% [markdown]
# ###  \[Hipótesis 2\]

# %% [markdown]
# Introducción Hipótesis

# %%
#desarrollo Hipótesis

# %%
#Grafico Hipótesis

# %% [markdown]
# Explicación de lo que se desarrolló para ver si se cumple o no la hipótesis planteada

# %% [markdown]
# La Hipótesis se cumple o no se cumple

# %% [markdown]
# ###  \[Hipótesis 3\]

# %% [markdown]
# Introducción Hipótesis

# %%
#desarrollo Hipótesis

# %%
#Grafico Hipótesis

# %% [markdown]
# Explicación de lo que se desarrolló para ver si se cumple o no la hipótesis planteada

# %% [markdown]
# La Hipótesis se cumple o no se cumple

# %% [markdown]
# ###  \[Hipótesis 4\]

# %% [markdown]
# Introducción Hipótesis

# %%
#desarrollo Hipótesis

# %%
#Grafico Hipótesis

# %% [markdown]
# Explicación de lo que se desarrolló para ver si se cumple o no la hipótesis planteada

# %% [markdown]
# La Hipótesis se cumple o no se cumple

# %% [markdown]
# ### \[Hipótesis 2\]

# %% [markdown]
# # ✅ Conclusión del equipo

# %% [markdown]
# Hemos podido observar que\.\.\.

# %% [markdown]
# # TERCERA ENTREGA

# %% [markdown]
# ## 👉🏻 Consigna

# %% [markdown]
# Entregar por grupo un solo notebook trabajando sobre el dataset elegido por el equipo\. El notebook debe incluir lo siguiente:

# %% [markdown]
# Introducción y descripción del dataset
# Planteamiento del objetivo del proyecto
# Planteamiento de hipótesis y resumen de las conclusiones sobre las hipótesis
# Análisis EDA
# Análisis univariado
# Análisis Bivariado y/o multivariado
# Graficas orientadas a la respuesta de estas 4 hipótesis
# Limpieza del dataset en caso de ser necesaria\.
# Aplicación de modelos de Regresión,
# Clasificación o Agrupación según lo planteado en el objetivo\.
# \(mínimo 3 modelos\)
# Métricas de evaluación del modelo aplicado
# Selección del modelo más indicado en base a las métricas\.

# %% [markdown]
# ## 🔍 Introducción

# %% [markdown]
# # 📁 Dataset elegido – \[Nombre del dataset\]

# %% [markdown]
# ## 📝 Descripción del Dataset

# %% [markdown]
# Describir de que se trata el dataset

# %% [markdown]
# ## Importación de Librerías

# %%
#Importación de librerías

# %% [markdown]
# ## 1\. Carga y exploración de datos

# %% [markdown]
# ###  \[Nombre de la acción\]

# %% [markdown]
# Introducción a la acción

# %%
# Código para cargar el dataset y mostrar estructura

# %% [markdown]
# Interpretación de la acción

# %% [markdown]
# ###  \[Nombre de la acción\]

# %% [markdown]
# Introducción a la acción

# %%
# Código para analizar el dataset y mostrar estructura

# %% [markdown]
# Interpretación de la acción

# %% [markdown]
# ## 2\. Visualizaciones y análisis

# %% [markdown]
# ###  \[Nombre del gráfico\]

# %% [markdown]
# Introducción al Gráfico 1

# %%
#Gráfico 1

# %% [markdown]
# 📌 Interpretación del gráfico

# %% [markdown]
# Introducción al Gráfico 2

# %%
#Gráfico 2

# %% [markdown]
# 📌 Interpretación del gráfico

# %% [markdown]
# Breve resumen del análisis: ¿Qué patrones se observan? ¿Hay calidad en los datos? ¿Qué variables resultan más interesantes?

# %% [markdown]
# # ✅ Conclusión del equipo

# %% [markdown]
# Después de analizar todos los datasets, el equipo ha decidido continuar el trabajo con el dataset:

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=2319643e-25a8-4d42-a202-f6094690deca' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' />
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
