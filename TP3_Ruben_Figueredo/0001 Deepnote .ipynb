# %% [markdown]
# # TP01 - Deepnote - Figueredo Ruben

# %%
Soy Ruben Figueredo y este es mi primer notebook en Deepnote. Actualmete estoy trabajando como Desarrollador ABAP.
De esta materia entre con la expectativa de adquirir habilidades prácticas y herramientas técnicas que me permitan automatizar tareas, 
analizar datos de forma inteligente y comprender el ecosistema actual de la IA aplicada.

# %%
print("Mi primer notebook en Deepnote")
# Out:
# Mi primer notebook en Deepnote

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=4b6514f3-3df5-49f8-b520-23e1dab14ad2' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' />
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
